# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Empty list for the cities
cities = []
# Find the nearest city for each latitude and longitude.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Add it to the cities list.
    if city not in cities:
        cities.append(city)

cities
# Out:
# ['raudeberg',
#  'solana beach',
#  'tungkang',
#  'hoquiam',
#  'biak',
#  'bluff',
#  'punta arenas',
#  'westport',
#  'ponta do sol',
#  'iqaluit',
#  'nizhneyansk',
#  'pevek',
#  'nemuro',
#  'georgetown',
#  'oskarshamn',
#  'rikitea',
#  'upernavik',
#  'kruisfontein',
#  'barrow',
#  'warmbad',
#  'provideniya',
#  'beloha',
#  'hermanus',
#  'ponta delgada',
#  'lasa',
#  'souillac',
#  'tambo',
#  'quatre cocos',
#  'castanos',
#  'montepuez',
#  'busselton',
#  'emerald',
#  'saint george',
#  'niteroi',
#  'arraial do cabo',
#  'severo-kurilsk',
#  'mrirt',
#  'ushuaia',
#  'illoqqortoormiut',
#  'port hedland',
#  'mezen',
#  'atuona',
#  'embonas',
#  'ola',
#  'marsa matruh',
#  'castro',
#  'luderitz',
#  'lithakia',
#  'deh rawud',
#  'chuy',
#  'acapulco',
#  'kerki',
#  'mannarakkat',
#  'narsaq',
#  'tahe',
#  'mokhotlong',
#  'dikson',
#  'sinjah',
#  'yar-sale',
#  'norsup',
#  'new norfolk',
#  'port alfred',
#  'kalmunai',
#  'hithadhoo',
#  'markova',
#  'namtsy',
#  'taolanaro',
#  'klaksvik',
#  'saint-philippe',
#  'vaini',
#  'cape town',
#  'roald',
#  'tasiilaq',
#  'geraldton',
#  'aripuana',
#  'mar del plata',
#  'los llanos de aridane',
#  'carnarvon',
#  'bodden town',
#  'avarua',
#  'hobart',
#  'mataura',
#  'port elizabeth',
#  'aykhal',
#  'richards bay',
#  'cidreira',
#  'sisimiut',
#  'yellowknife',
#  'matam',
#  'palabuhanratu',
#  'oksovskiy',
#  'santa comba',
#  'norman wells',
#  'waddan',
#  'korla',
#  'ribeira grande',
#  'victoria',
#  'champerico',
#  'khatanga',
#  'aleksandrovsk-sakhalinskiy',
#  'lebu',
#  'qaanaaq',
#  'himora',
#  'hasaki',
#  'shenzhen',
#  'vila franca do campo',
#  'hamilton',
#  'sao felix do xingu',
#  'perevolotskiy',
#  'port hardy',
#  'ben tre',
#  'manadhoo',
#  'kapaa',
#  'baghdad',
#  'jamestown',
#  'ugoofaaru',
#  'saleaula',
#  'birao',
#  'toliary',
#  'butaritari',
#  'kovur',
#  'tuktoyaktuk',
#  'moundou',
#  'baykit',
#  'deputatskiy',
#  'santo antonio do ica',
#  'aketi',
#  'khvoynaya',
#  'dalianwan',
#  'saldanha',
#  'hilo',
#  'esperance',
#  'vila velha',
#  'camocim',
#  'barentsburg',
#  'rawson',
#  'east london',
#  'severiano melo',
#  'chokurdakh',
#  'kurilsk',
#  'san fernando',
#  'mayo',
#  'nikolskoye',
#  'north bend',
#  'clinton',
#  'athabasca',
#  'lata',
#  'sentyabrskiy',
#  'albany',
#  'ha giang',
#  'airai',
#  'benguela',
#  'abalak',
#  'kahului',
#  'clyde river',
#  'termoli',
#  'bambous virieux',
#  'chissamba',
#  'killybegs',
#  'caracuaro',
#  'humaita',
#  'san patricio',
#  'portland',
#  'sao filipe',
#  'honiara',
#  'naze',
#  'jagdalpur',
#  'pisco',
#  'nome',
#  'paamiut',
#  'grand river south east',
#  'puerto ayora',
#  'luwuk',
#  'isangel',
#  'juneau',
#  'carutapera',
#  'bethel',
#  'cedartown',
#  'sur',
#  'honningsvag',
#  'tual',
#  'mawlaik',
#  'hofn',
#  'hakkari',
#  'bargal',
#  'smidovich',
#  'obihiro',
#  'george town',
#  'kamenka',
#  'mango',
#  'naryan-mar',
#  'attawapiskat',
#  'mecca',
#  'kamenskoye',
#  'asau',
#  'saint-louis',
#  'karamea',
#  'rudnogorsk',
#  'lazaro cardenas',
#  'bredasdorp',
#  'kodiak',
#  'celestun',
#  'prilep',
#  'marsh harbour',
#  'marcona',
#  'tabou',
#  'hambantota',
#  'the valley',
#  'san quintin',
#  'guerrero negro',
#  'buala',
#  'paso de los toros',
#  'salalah',
#  'iranshahr',
#  'caravelas',
#  'cheremukhovo',
#  'saskylakh',
#  'cherskiy',
#  'barcelos',
#  'fereydun kenar',
#  'lavrentiya',
#  'ilulissat',
#  'palu',
#  'kaitangata',
#  'college',
#  'tiksi',
#  'egvekinot',
#  'chingola',
#  'solnechnyy',
#  'itarema',
#  'murgab',
#  'lompoc',
#  'saint-francois',
#  'monte carmelo',
#  'edd',
#  'bonthe',
#  'mount isa',
#  'ulety',
#  'coquimbo',
#  'lagoa',
#  'fethiye',
#  'husavik',
#  'maragogi',
#  'upplands-vasby',
#  'labuhan',
#  'inzhavino',
#  'saint anthony',
#  'budelsdorf',
#  'kingston',
#  'faanui',
#  'eskasem',
#  'yola',
#  'rucphen',
#  'bilma',
#  'yichang',
#  'kulai',
#  'black river',
#  'fort nelson',
#  'sembakung',
#  'namatanai',
#  'usila',
#  'nioro',
#  'chivay',
#  'rock springs',
#  'monrovia',
#  'torbay',
#  'praxedis guerrero',
#  'meulaboh',
#  'teguise',
#  'namibe',
#  'matay',
#  'la ronge',
#  'ondorhaan',
#  'chapais',
#  'waipawa',
#  'vylgort',
#  'thompson',
#  'zinder',
#  'oranjemund',
#  'palana',
#  'tanout',
#  'burgeo',
#  'katobu',
#  'port hawkesbury',
#  'phan thiet',
#  'mahebourg',
#  'rolim de moura',
#  'jalu',
#  'gravelbourg',
#  'tambacounda',
#  'anadyr',
#  'dubai',
#  'teya',
#  'bathsheba',
#  'amderma',
#  'zambezi',
#  'belushya guba',
#  'bambanglipuro',
#  'doha',
#  'alice springs',
#  'pierre',
#  'ancud',
#  'faya',
#  'shahrud',
#  'bandarbeyla',
#  'curaca',
#  'boddam',
#  'san vicente',
#  'pangnirtung',
#  'southbridge',
#  'san cristobal',
#  'dondaicha',
#  'batagay',
#  'vestmannaeyjar',
#  'qurayyat',
#  'yei',
#  'tigil',
#  'gornyy',
#  'mindelo',
#  'malakal',
#  'kidal',
#  'port macquarie',
#  'flinders',
#  'zheleznodorozhnyy',
#  'ginda',
#  'mys shmidta',
#  'kismayo',
#  'bonavista',
#  'kangaatsiaq',
#  'wahran',
#  'leoben',
#  'linqiong',
#  'sitka',
#  'pacific grove',
#  'manokwari',
#  'gillette',
#  'burgos',
#  'aksarka',
#  'gurgan',
#  'santa cruz',
#  'sukumo',
#  'craigieburn',
#  'banda aceh',
#  'kleive',
#  'fort portal',
#  'tunceli',
#  'kankaanpaa',
#  'youkounkoun',
#  'la rioja',
#  'doka',
#  'ahipara',
#  'arlit',
#  'gazojak',
#  'khilok',
#  'kolokani',
#  'halalo',
#  'kindu',
#  'gurupa',
#  'san rafael del sur',
#  'asosa',
#  'karaton',
#  'lubu',
#  'zyryanka',
#  'bauchi',
#  'saint-joseph',
#  'taltal',
#  'bengkulu',
#  'sinnamary',
#  'nambucca heads',
#  'kochki',
#  'taoudenni',
#  'longyearbyen',
#  'abha',
#  'mbandaka',
#  'maryville',
#  'opuwo',
#  'laguna',
#  'bolungarvik',
#  'shimoda',
#  'baruun-urt',
#  'umtata',
#  'maniitsoq',
#  'okha',
#  'pandharpur',
#  'dera bugti',
#  'mehamn',
#  'viligili',
#  'komsomolskiy',
#  'dauphin',
#  'markala',
#  'byron bay',
#  'gilgit',
#  'lufilufi',
#  'alakurtti',
#  'nizwa',
#  'kavieng',
#  'tamandare',
#  'zhezkazgan',
#  'puerto narino',
#  'cianorte',
#  'mana',
#  'sakakah',
#  'astana',
#  'alyangula',
#  'dingle',
#  'formoso do araguaia',
#  'sorland',
#  'olga',
#  'ostrovnoy',
#  'sioux lookout',
#  'una',
#  'okhotsk',
#  'dubbo',
#  'samusu',
#  'lovozero',
#  'lorengau',
#  'cayenne',
#  'ixtapa',
#  'nuuk',
#  'usinsk',
#  'solovetskiy',
#  'shellbrook',
#  'haines junction',
#  'kiunga',
#  'tuatapere',
#  'vardo',
#  'trelew',
#  'hun',
#  'cumberland',
#  'sola',
#  'alto araguaia',
#  'saint-augustin',
#  'aasiaat',
#  'yarmouth',
#  'krasnoselkup',
#  'quelimane',
#  'tlaltenango',
#  'bucerias',
#  'kargat',
#  'lima',
#  'tyshkivka',
#  'harper',
#  'mulchen',
#  'huayucachi',
#  'fort thomas',
#  'germersheim',
#  'lakatoro',
#  'skalistyy',
#  'atar',
#  'katherine',
#  'srednekolymsk',
#  'norrtalje',
#  'lillooet',
#  'eureka',
#  'mildura',
#  'tupaciguara',
#  'ruatoria',
#  'hovd',
#  'joshimath',
#  'inhambane',
#  'uwayl',
#  'beidao',
#  'emilio carranza',
#  'ejea de los caballeros',
#  'vaitupu',
#  'mayskiy',
#  'kyren',
#  'touros',
#  'berlevag',
#  'melioratorov',
#  'codrington',
#  'san carlos de bariloche',
#  'otatitlan',
#  'kulhudhuffushi',
#  'bukachacha',
#  'fortuna',
#  'vastervik',
#  'hervey bay',
#  'xining',
#  'nguiu',
#  'mahibadhoo',
#  'barra patuca',
#  'georgiyevka',
#  'makakilo city',
#  'bulgan',
#  'qianan',
#  'katangli',
#  'palauig',
#  'punta de piedra',
#  'nabire',
#  'nosy varika',
#  'torre del campo',
#  'limbang',
#  'bogorodskoye',
#  'samana',
#  'onega',
#  'cabo san lucas',
#  'tomatlan',
#  'anloga',
#  'halifax',
#  'tessalit',
#  'zabid',
#  'novo aripuana',
#  'mattru',
#  'santa ines',
#  'rosita',
#  'el paso',
#  'golden',
#  'bilibino',
#  'saint-leu',
#  'marrakesh',
#  'poum',
#  'oranjestad',
#  'tazovskiy',
#  'utiroa',
#  'jutai',
#  'chirongui',
#  'andarab',
#  'tiarei',
#  'angoram',
#  'hohhot',
#  'ribnica',
#  'olafsvik',
#  'clarence town',
#  'paita',
#  'menongue',
#  'port lincoln',
#  'yumen',
#  'calabozo',
#  'sharjah',
#  'huinan',
#  'tumannyy',
#  'ambilobe',
#  'salinas',
#  'victor harbor',
#  'puebloviejo',
#  'udalguri',
#  'asht',
#  'yanan',
#  'beringovskiy',
#  'madang',
#  'dahra',
#  'bushehr',
#  'kavaratti',
#  'ostrovtsy',
#  'santiago de cao',
#  'karkaralinsk',
#  'bontang',
#  'gravdal',
#  'walvis bay',
#  'axtla',
#  'rexburg',
#  'ambulu',
#  'rancho palos verdes',
#  'gornyak',
#  'aksu',
#  'konstantinovka',
#  'picayune',
#  'prizren',
#  'mitchell',
#  'palmer',
#  'iwanai',
#  'katsuura',
#  'buri',
#  'vilhena',
#  'milkovo',
#  'luanda',
#  'yanam',
#  'gubskaya',
#  'hobyo',
#  'sfantu gheorghe',
#  'panzhihua',
#  'auki',
#  'ahumada',
#  'mizdah',
#  'nanortalik',
#  'skibbereen',
#  'cockburn town',
#  'laval',
#  'gambela',
#  'curup',
#  'abnub',
#  'ternate',
#  'nyurba',
#  'vuktyl',
#  'gunjur',
#  'augusto correa',
#  'purkersdorf',
#  'den helder',
#  'dalvik',
#  'alofi',
#  'ozinki',
#  'imeni zhelyabova',
#  'kota kinabalu',
#  'rabo de peixe',
#  'ito',
#  'wausau',
#  'formosa',
#  'kununurra',
#  'armacao dos buzios',
#  'nhulunbuy',
#  'ballina',
#  'sydney',
#  'mahadday weyne',
#  'alacranes',
#  'broome',
#  'coahuayana',
#  'casa nova',
#  'det udom',
#  'khorixas',
#  'leighton buzzard',
#  'nador',
#  'praia da vitoria',
#  'yaan',
#  'sorong',
#  'gizo',
#  'lawan kuda baharu',
#  'mayya',
#  'galle',
#  'yucca valley',
#  'tsihombe',
#  'chikwawa',
#  'grand-santi',
#  'maniwaki',
#  'rio das pedras',
#  'port blair',
#  'ahar',
#  'dzhusaly',
#  'mayumba',
#  'tromso',
#  'villarrica',
#  'motala',
#  'vredendal',
#  'afmadu',
#  'wanning',
#  'fare',
#  'bennington',
#  'padang',
#  'tidore',
#  'traralgon',
#  'ampanihy',
#  'tilichiki',
#  'vestmanna',
#  'kijang',
#  'kautokeino',
#  'nishihara',
#  'lindi',
#  'ialibu',
#  'trairi',
#  'grindavik',
#  'lukang',
#  'talnakh',
#  'svetlogorsk',
#  'paramonga',
#  'fort saint john',
#  'sao joao da barra',
#  'belyy yar',
#  'mehran',
#  'zaysan',
#  'vestbygda',
#  'quime',
#  'thaba-tseka',
#  'linxia',
#  'necochea',
#  'sompeta',
#  'xichang',
#  'leningradskiy',
#  'graham',
#  'arenys de mar',
#  'bereda',
#  'dunedin',
#  'carcassonne',
#  'nargana',
#  'omboue',
#  'aban',
#  'zomin',
#  'sabibah',
#  'camacha',
#  'jerusalem',
#  'grand centre',
#  'yacuiba',
#  'cazaje',
#  'smoky lake',
#  'tubruq',
#  'puqi',
#  'ulaanbaatar',
#  'dali',
#  'aljezur',
#  'gazanjyk',
#  'gornopravdinsk',
#  'kysyl-syr',
#  'lemoore',
#  'qaqortoq',
#  'velika kladusa',
#  'plettenberg bay',
#  'zitlala',
#  'dole',
#  'sechura',
#  'adrar',
#  'pokhara',
#  'bosobolo',
#  'scarborough',
#  'po',
#  'mitsamiouli',
#  'rongcheng',
#  'karratha',
#  'nelson bay',
#  'kloulklubed',
#  'coihaique',
#  'ataco',
#  'vega de alatorre',
#  'raypur',
#  'marana',
#  'el cope',
#  'turukhansk',
#  'nianzishan',
#  'bitam',
#  'tlahualilo',
#  'kralendijk',
#  'bundaberg',
#  'kropotkin',
#  'liwale',
#  'peniche',
#  'safut',
#  'kondopoga',
#  'inirida',
#  'novyy urengoy',
#  'lander',
#  'madison',
#  'ibipeba',
#  'khandagayty',
#  'hami',
#  'farafangana',
#  'pouembout',
#  'atasu',
#  'muros',
#  'sinkat',
#  'ust-nera',
#  'atbasar',
#  'visnes',
#  'itamaraca',
#  'jumla',
#  'suntar',
#  'mackenzie',
#  'casa grande',
#  'karaul',
#  'palma soriano',
#  'ilinskiy',
#  'matara',
#  'dong hoi',
#  'vallenar',
#  'emba',
#  'vila',
#  'sambava',
#  'rio grande',
#  'garissa',
#  'burns lake',
#  'mahon',
#  'tongzi',
#  'paradwip',
#  'port-gentil',
#  'mbanza-ngungu',
#  'lipin bor',
#  'ulcinj',
#  'kirakira',
#  'zhangye',
#  'morondava',
#  'chattanooga',
#  'saint-pierre']

# %%
len(cities)
# Out:
# 769

# %%
# Empty list.
city_data = []

# Start Process.
print("Start Process")

# Counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("Complete")
# Out:
# Start Process
# Processing Record 1 of Set 1 | raudeberg
# Processing Record 2 of Set 1 | solana beach
# Processing Record 3 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 1 | hoquiam
# Processing Record 5 of Set 1 | biak
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | westport
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | nemuro
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | oskarshamn
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | warmbad
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | beloha
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | ponta delgada
# Processing Record 25 of Set 1 | lasa
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | tambo
# Processing Record 28 of Set 1 | quatre cocos
# Processing Record 29 of Set 1 | castanos
# Processing Record 30 of Set 1 | montepuez
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | emerald
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | niteroi
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | port hedland
# Processing Record 41 of Set 1 | mezen
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | embonas
# Processing Record 44 of Set 1 | ola
# Processing Record 45 of Set 1 | marsa matruh
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | lithakia
# Processing Record 49 of Set 1 | deh rawud
# City not found. Skipping...
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | acapulco
# Processing Record 2 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 3 of Set 2 | mannarakkat
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | tahe
# Processing Record 6 of Set 2 | mokhotlong
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | sinjah
# City not found. Skipping...
# Processing Record 9 of Set 2 | yar-sale
# Processing Record 10 of Set 2 | norsup
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | kalmunai
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | markova
# Processing Record 16 of Set 2 | namtsy
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | roald
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | aripuana
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | los llanos de aridane
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | bodden town
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | aykhal
# Processing Record 35 of Set 2 | richards bay
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | sisimiut
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | matam
# Processing Record 40 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 2 | oksovskiy
# Processing Record 42 of Set 2 | santa comba
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | waddan
# Processing Record 45 of Set 2 | korla
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | champerico
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | aleksandrovsk-sakhalinskiy
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | himora
# City not found. Skipping...
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | shenzhen
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | hamilton
# Processing Record 8 of Set 3 | sao felix do xingu
# Processing Record 9 of Set 3 | perevolotskiy
# Processing Record 10 of Set 3 | port hardy
# Processing Record 11 of Set 3 | ben tre
# Processing Record 12 of Set 3 | manadhoo
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | baghdad
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | ugoofaaru
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | birao
# Processing Record 19 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | kovur
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | moundou
# Processing Record 24 of Set 3 | baykit
# Processing Record 25 of Set 3 | deputatskiy
# Processing Record 26 of Set 3 | santo antonio do ica
# Processing Record 27 of Set 3 | aketi
# Processing Record 28 of Set 3 | khvoynaya
# Processing Record 29 of Set 3 | dalianwan
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | camocim
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | rawson
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | severiano melo
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | kurilsk
# Processing Record 41 of Set 3 | san fernando
# Processing Record 42 of Set 3 | mayo
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | north bend
# Processing Record 45 of Set 3 | clinton
# Processing Record 46 of Set 3 | athabasca
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 3 | albany
# Processing Record 50 of Set 3 | ha giang
# Processing Record 1 of Set 4 | airai
# Processing Record 2 of Set 4 | benguela
# Processing Record 3 of Set 4 | abalak
# Processing Record 4 of Set 4 | kahului
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | termoli
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | chissamba
# Processing Record 9 of Set 4 | killybegs
# Processing Record 10 of Set 4 | caracuaro
# Processing Record 11 of Set 4 | humaita
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | portland
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | honiara
# Processing Record 16 of Set 4 | naze
# Processing Record 17 of Set 4 | jagdalpur
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | paamiut
# Processing Record 21 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | luwuk
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | juneau
# Processing Record 26 of Set 4 | carutapera
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | cedartown
# Processing Record 29 of Set 4 | sur
# Processing Record 30 of Set 4 | honningsvag
# Processing Record 31 of Set 4 | tual
# Processing Record 32 of Set 4 | mawlaik
# Processing Record 33 of Set 4 | hofn
# Processing Record 34 of Set 4 | hakkari
# Processing Record 35 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 4 | smidovich
# Processing Record 37 of Set 4 | obihiro
# Processing Record 38 of Set 4 | george town
# Processing Record 39 of Set 4 | kamenka
# Processing Record 40 of Set 4 | mango
# Processing Record 41 of Set 4 | naryan-mar
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | mecca
# Processing Record 44 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 4 | asau
# Processing Record 46 of Set 4 | saint-louis
# Processing Record 47 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 4 | rudnogorsk
# Processing Record 49 of Set 4 | lazaro cardenas
# Processing Record 50 of Set 4 | bredasdorp
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | celestun
# Processing Record 3 of Set 5 | prilep
# Processing Record 4 of Set 5 | marsh harbour
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | tabou
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | the valley
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | buala
# Processing Record 12 of Set 5 | paso de los toros
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | iranshahr
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | cheremukhovo
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | cherskiy
# Processing Record 19 of Set 5 | barcelos
# Processing Record 20 of Set 5 | fereydun kenar
# Processing Record 21 of Set 5 | lavrentiya
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | palu
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | college
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | egvekinot
# Processing Record 28 of Set 5 | chingola
# Processing Record 29 of Set 5 | solnechnyy
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | murgab
# Processing Record 32 of Set 5 | lompoc
# Processing Record 33 of Set 5 | saint-francois
# Processing Record 34 of Set 5 | monte carmelo
# Processing Record 35 of Set 5 | edd
# Processing Record 36 of Set 5 | bonthe
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | ulety
# Processing Record 39 of Set 5 | coquimbo
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | fethiye
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | upplands-vasby
# City not found. Skipping...
# Processing Record 45 of Set 5 | labuhan
# Processing Record 46 of Set 5 | inzhavino
# Processing Record 47 of Set 5 | saint anthony
# Processing Record 48 of Set 5 | budelsdorf
# Processing Record 49 of Set 5 | kingston
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 2 of Set 6 | yola
# Processing Record 3 of Set 6 | rucphen
# Processing Record 4 of Set 6 | bilma
# Processing Record 5 of Set 6 | yichang
# Processing Record 6 of Set 6 | kulai
# Processing Record 7 of Set 6 | black river
# Processing Record 8 of Set 6 | fort nelson
# Processing Record 9 of Set 6 | sembakung
# Processing Record 10 of Set 6 | namatanai
# Processing Record 11 of Set 6 | usila
# City not found. Skipping...
# Processing Record 12 of Set 6 | nioro
# Processing Record 13 of Set 6 | chivay
# Processing Record 14 of Set 6 | rock springs
# Processing Record 15 of Set 6 | monrovia
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | praxedis guerrero
# Processing Record 18 of Set 6 | meulaboh
# Processing Record 19 of Set 6 | teguise
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | matay
# Processing Record 22 of Set 6 | la ronge
# Processing Record 23 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 6 | chapais
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | vylgort
# City not found. Skipping...
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | zinder
# Processing Record 29 of Set 6 | oranjemund
# Processing Record 30 of Set 6 | palana
# Processing Record 31 of Set 6 | tanout
# Processing Record 32 of Set 6 | burgeo
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | port hawkesbury
# Processing Record 35 of Set 6 | phan thiet
# Processing Record 36 of Set 6 | mahebourg
# Processing Record 37 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 6 | jalu
# Processing Record 39 of Set 6 | gravelbourg
# Processing Record 40 of Set 6 | tambacounda
# Processing Record 41 of Set 6 | anadyr
# Processing Record 42 of Set 6 | dubai
# Processing Record 43 of Set 6 | teya
# Processing Record 44 of Set 6 | bathsheba
# Processing Record 45 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 6 | zambezi
# Processing Record 47 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 6 | bambanglipuro
# Processing Record 49 of Set 6 | doha
# Processing Record 50 of Set 6 | alice springs
# Processing Record 1 of Set 7 | pierre
# Processing Record 2 of Set 7 | ancud
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | shahrud
# Processing Record 5 of Set 7 | bandarbeyla
# Processing Record 6 of Set 7 | curaca
# Processing Record 7 of Set 7 | boddam
# Processing Record 8 of Set 7 | san vicente
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | southbridge
# Processing Record 11 of Set 7 | san cristobal
# Processing Record 12 of Set 7 | dondaicha
# Processing Record 13 of Set 7 | batagay
# Processing Record 14 of Set 7 | vestmannaeyjar
# Processing Record 15 of Set 7 | qurayyat
# Processing Record 16 of Set 7 | yei
# Processing Record 17 of Set 7 | tigil
# Processing Record 18 of Set 7 | gornyy
# Processing Record 19 of Set 7 | mindelo
# Processing Record 20 of Set 7 | malakal
# Processing Record 21 of Set 7 | kidal
# Processing Record 22 of Set 7 | port macquarie
# Processing Record 23 of Set 7 | flinders
# Processing Record 24 of Set 7 | zheleznodorozhnyy
# Processing Record 25 of Set 7 | ginda
# Processing Record 26 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 7 | kismayo
# Processing Record 28 of Set 7 | bonavista
# Processing Record 29 of Set 7 | kangaatsiaq
# Processing Record 30 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 7 | leoben
# Processing Record 32 of Set 7 | linqiong
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | manokwari
# Processing Record 36 of Set 7 | gillette
# Processing Record 37 of Set 7 | burgos
# Processing Record 38 of Set 7 | aksarka
# Processing Record 39 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 7 | santa cruz
# Processing Record 41 of Set 7 | sukumo
# Processing Record 42 of Set 7 | craigieburn
# Processing Record 43 of Set 7 | banda aceh
# Processing Record 44 of Set 7 | kleive
# Processing Record 45 of Set 7 | fort portal
# Processing Record 46 of Set 7 | tunceli
# Processing Record 47 of Set 7 | kankaanpaa
# Processing Record 48 of Set 7 | youkounkoun
# Processing Record 49 of Set 7 | la rioja
# Processing Record 50 of Set 7 | doka
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | arlit
# Processing Record 3 of Set 8 | gazojak
# Processing Record 4 of Set 8 | khilok
# Processing Record 5 of Set 8 | kolokani
# Processing Record 6 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 8 | kindu
# Processing Record 8 of Set 8 | gurupa
# Processing Record 9 of Set 8 | san rafael del sur
# Processing Record 10 of Set 8 | asosa
# Processing Record 11 of Set 8 | karaton
# Processing Record 12 of Set 8 | lubu
# Processing Record 13 of Set 8 | zyryanka
# Processing Record 14 of Set 8 | bauchi
# Processing Record 15 of Set 8 | saint-joseph
# Processing Record 16 of Set 8 | taltal
# Processing Record 17 of Set 8 | bengkulu
# Processing Record 18 of Set 8 | sinnamary
# Processing Record 19 of Set 8 | nambucca heads
# Processing Record 20 of Set 8 | kochki
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | longyearbyen
# Processing Record 23 of Set 8 | abha
# Processing Record 24 of Set 8 | mbandaka
# Processing Record 25 of Set 8 | maryville
# Processing Record 26 of Set 8 | opuwo
# Processing Record 27 of Set 8 | laguna
# Processing Record 28 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 8 | shimoda
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | umtata
# Processing Record 32 of Set 8 | maniitsoq
# Processing Record 33 of Set 8 | okha
# Processing Record 34 of Set 8 | pandharpur
# Processing Record 35 of Set 8 | dera bugti
# Processing Record 36 of Set 8 | mehamn
# Processing Record 37 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | dauphin
# Processing Record 40 of Set 8 | markala
# Processing Record 41 of Set 8 | byron bay
# Processing Record 42 of Set 8 | gilgit
# Processing Record 43 of Set 8 | lufilufi
# Processing Record 44 of Set 8 | alakurtti
# Processing Record 45 of Set 8 | nizwa
# Processing Record 46 of Set 8 | kavieng
# Processing Record 47 of Set 8 | tamandare
# Processing Record 48 of Set 8 | zhezkazgan
# Processing Record 49 of Set 8 | puerto narino
# Processing Record 50 of Set 8 | cianorte
# Processing Record 1 of Set 9 | mana
# Processing Record 2 of Set 9 | sakakah
# Processing Record 3 of Set 9 | astana
# Processing Record 4 of Set 9 | alyangula
# Processing Record 5 of Set 9 | dingle
# Processing Record 6 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 9 | sorland
# Processing Record 8 of Set 9 | olga
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | sioux lookout
# Processing Record 11 of Set 9 | una
# Processing Record 12 of Set 9 | okhotsk
# Processing Record 13 of Set 9 | dubbo
# Processing Record 14 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 9 | lovozero
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | cayenne
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | nuuk
# Processing Record 20 of Set 9 | usinsk
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | shellbrook
# Processing Record 23 of Set 9 | haines junction
# Processing Record 24 of Set 9 | kiunga
# Processing Record 25 of Set 9 | tuatapere
# Processing Record 26 of Set 9 | vardo
# Processing Record 27 of Set 9 | trelew
# Processing Record 28 of Set 9 | hun
# Processing Record 29 of Set 9 | cumberland
# Processing Record 30 of Set 9 | sola
# Processing Record 31 of Set 9 | alto araguaia
# Processing Record 32 of Set 9 | saint-augustin
# Processing Record 33 of Set 9 | aasiaat
# Processing Record 34 of Set 9 | yarmouth
# Processing Record 35 of Set 9 | krasnoselkup
# Processing Record 36 of Set 9 | quelimane
# Processing Record 37 of Set 9 | tlaltenango
# Processing Record 38 of Set 9 | bucerias
# Processing Record 39 of Set 9 | kargat
# Processing Record 40 of Set 9 | lima
# Processing Record 41 of Set 9 | tyshkivka
# Processing Record 42 of Set 9 | harper
# Processing Record 43 of Set 9 | mulchen
# Processing Record 44 of Set 9 | huayucachi
# Processing Record 45 of Set 9 | fort thomas
# Processing Record 46 of Set 9 | germersheim
# Processing Record 47 of Set 9 | lakatoro
# Processing Record 48 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | katherine
# Processing Record 1 of Set 10 | srednekolymsk
# Processing Record 2 of Set 10 | norrtalje
# Processing Record 3 of Set 10 | lillooet
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | mildura
# Processing Record 6 of Set 10 | tupaciguara
# Processing Record 7 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | joshimath
# Processing Record 10 of Set 10 | inhambane
# Processing Record 11 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 12 of Set 10 | beidao
# Processing Record 13 of Set 10 | emilio carranza
# Processing Record 14 of Set 10 | ejea de los caballeros
# Processing Record 15 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 10 | mayskiy
# Processing Record 17 of Set 10 | kyren
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | berlevag
# Processing Record 20 of Set 10 | melioratorov
# Processing Record 21 of Set 10 | codrington
# Processing Record 22 of Set 10 | san carlos de bariloche
# Processing Record 23 of Set 10 | otatitlan
# Processing Record 24 of Set 10 | kulhudhuffushi
# Processing Record 25 of Set 10 | bukachacha
# Processing Record 26 of Set 10 | fortuna
# Processing Record 27 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 28 of Set 10 | hervey bay
# Processing Record 29 of Set 10 | xining
# Processing Record 30 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 10 | mahibadhoo
# Processing Record 32 of Set 10 | barra patuca
# Processing Record 33 of Set 10 | georgiyevka
# Processing Record 34 of Set 10 | makakilo city
# Processing Record 35 of Set 10 | bulgan
# Processing Record 36 of Set 10 | qianan
# Processing Record 37 of Set 10 | katangli
# Processing Record 38 of Set 10 | palauig
# Processing Record 39 of Set 10 | punta de piedra
# Processing Record 40 of Set 10 | nabire
# Processing Record 41 of Set 10 | nosy varika
# Processing Record 42 of Set 10 | torre del campo
# Processing Record 43 of Set 10 | limbang
# Processing Record 44 of Set 10 | bogorodskoye
# Processing Record 45 of Set 10 | samana
# Processing Record 46 of Set 10 | onega
# Processing Record 47 of Set 10 | cabo san lucas
# Processing Record 48 of Set 10 | tomatlan
# Processing Record 49 of Set 10 | anloga
# Processing Record 50 of Set 10 | halifax
# Processing Record 1 of Set 11 | tessalit
# Processing Record 2 of Set 11 | zabid
# Processing Record 3 of Set 11 | novo aripuana
# Processing Record 4 of Set 11 | mattru
# Processing Record 5 of Set 11 | santa ines
# Processing Record 6 of Set 11 | rosita
# Processing Record 7 of Set 11 | el paso
# Processing Record 8 of Set 11 | golden
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | saint-leu
# Processing Record 11 of Set 11 | marrakesh
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | oranjestad
# Processing Record 14 of Set 11 | tazovskiy
# Processing Record 15 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 11 | jutai
# Processing Record 17 of Set 11 | chirongui
# Processing Record 18 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 19 of Set 11 | tiarei
# Processing Record 20 of Set 11 | angoram
# Processing Record 21 of Set 11 | hohhot
# Processing Record 22 of Set 11 | ribnica
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | clarence town
# Processing Record 25 of Set 11 | paita
# Processing Record 26 of Set 11 | menongue
# Processing Record 27 of Set 11 | port lincoln
# Processing Record 28 of Set 11 | yumen
# Processing Record 29 of Set 11 | calabozo
# Processing Record 30 of Set 11 | sharjah
# Processing Record 31 of Set 11 | huinan
# Processing Record 32 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 11 | ambilobe
# Processing Record 34 of Set 11 | salinas
# Processing Record 35 of Set 11 | victor harbor
# Processing Record 36 of Set 11 | puebloviejo
# Processing Record 37 of Set 11 | udalguri
# Processing Record 38 of Set 11 | asht
# City not found. Skipping...
# Processing Record 39 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 11 | beringovskiy
# Processing Record 41 of Set 11 | madang
# Processing Record 42 of Set 11 | dahra
# Processing Record 43 of Set 11 | bushehr
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | ostrovtsy
# Processing Record 46 of Set 11 | santiago de cao
# Processing Record 47 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | bontang
# Processing Record 49 of Set 11 | gravdal
# Processing Record 50 of Set 11 | walvis bay
# Processing Record 1 of Set 12 | axtla
# City not found. Skipping...
# Processing Record 2 of Set 12 | rexburg
# Processing Record 3 of Set 12 | ambulu
# Processing Record 4 of Set 12 | rancho palos verdes
# Processing Record 5 of Set 12 | gornyak
# Processing Record 6 of Set 12 | aksu
# Processing Record 7 of Set 12 | konstantinovka
# Processing Record 8 of Set 12 | picayune
# Processing Record 9 of Set 12 | prizren
# Processing Record 10 of Set 12 | mitchell
# Processing Record 11 of Set 12 | palmer
# Processing Record 12 of Set 12 | iwanai
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | buri
# Processing Record 15 of Set 12 | vilhena
# Processing Record 16 of Set 12 | milkovo
# Processing Record 17 of Set 12 | luanda
# Processing Record 18 of Set 12 | yanam
# Processing Record 19 of Set 12 | gubskaya
# Processing Record 20 of Set 12 | hobyo
# Processing Record 21 of Set 12 | sfantu gheorghe
# Processing Record 22 of Set 12 | panzhihua
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 25 of Set 12 | mizdah
# Processing Record 26 of Set 12 | nanortalik
# Processing Record 27 of Set 12 | skibbereen
# Processing Record 28 of Set 12 | cockburn town
# Processing Record 29 of Set 12 | laval
# Processing Record 30 of Set 12 | gambela
# Processing Record 31 of Set 12 | curup
# Processing Record 32 of Set 12 | abnub
# Processing Record 33 of Set 12 | ternate
# Processing Record 34 of Set 12 | nyurba
# Processing Record 35 of Set 12 | vuktyl
# Processing Record 36 of Set 12 | gunjur
# Processing Record 37 of Set 12 | augusto correa
# Processing Record 38 of Set 12 | purkersdorf
# Processing Record 39 of Set 12 | den helder
# Processing Record 40 of Set 12 | dalvik
# Processing Record 41 of Set 12 | alofi
# Processing Record 42 of Set 12 | ozinki
# Processing Record 43 of Set 12 | imeni zhelyabova
# Processing Record 44 of Set 12 | kota kinabalu
# Processing Record 45 of Set 12 | rabo de peixe
# Processing Record 46 of Set 12 | ito
# Processing Record 47 of Set 12 | wausau
# Processing Record 48 of Set 12 | formosa
# Processing Record 49 of Set 12 | kununurra
# Processing Record 50 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 13 | nhulunbuy
# Processing Record 2 of Set 13 | ballina
# Processing Record 3 of Set 13 | sydney
# Processing Record 4 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 13 | alacranes
# Processing Record 6 of Set 13 | broome
# Processing Record 7 of Set 13 | coahuayana
# Processing Record 8 of Set 13 | casa nova
# Processing Record 9 of Set 13 | det udom
# Processing Record 10 of Set 13 | khorixas
# Processing Record 11 of Set 13 | leighton buzzard
# Processing Record 12 of Set 13 | nador
# Processing Record 13 of Set 13 | praia da vitoria
# Processing Record 14 of Set 13 | yaan
# Processing Record 15 of Set 13 | sorong
# Processing Record 16 of Set 13 | gizo
# Processing Record 17 of Set 13 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 18 of Set 13 | mayya
# Processing Record 19 of Set 13 | galle
# Processing Record 20 of Set 13 | yucca valley
# Processing Record 21 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 13 | chikwawa
# Processing Record 23 of Set 13 | grand-santi
# Processing Record 24 of Set 13 | maniwaki
# Processing Record 25 of Set 13 | rio das pedras
# Processing Record 26 of Set 13 | port blair
# Processing Record 27 of Set 13 | ahar
# Processing Record 28 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 13 | mayumba
# Processing Record 30 of Set 13 | tromso
# Processing Record 31 of Set 13 | villarrica
# Processing Record 32 of Set 13 | motala
# Processing Record 33 of Set 13 | vredendal
# Processing Record 34 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 35 of Set 13 | wanning
# Processing Record 36 of Set 13 | fare
# Processing Record 37 of Set 13 | bennington
# Processing Record 38 of Set 13 | padang
# Processing Record 39 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 13 | traralgon
# Processing Record 41 of Set 13 | ampanihy
# Processing Record 42 of Set 13 | tilichiki
# Processing Record 43 of Set 13 | vestmanna
# Processing Record 44 of Set 13 | kijang
# Processing Record 45 of Set 13 | kautokeino
# Processing Record 46 of Set 13 | nishihara
# Processing Record 47 of Set 13 | lindi
# Processing Record 48 of Set 13 | ialibu
# Processing Record 49 of Set 13 | trairi
# Processing Record 50 of Set 13 | grindavik
# Processing Record 1 of Set 14 | lukang
# Processing Record 2 of Set 14 | talnakh
# Processing Record 3 of Set 14 | svetlogorsk
# Processing Record 4 of Set 14 | paramonga
# Processing Record 5 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 14 | sao joao da barra
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | mehran
# Processing Record 9 of Set 14 | zaysan
# Processing Record 10 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 11 of Set 14 | quime
# Processing Record 12 of Set 14 | thaba-tseka
# Processing Record 13 of Set 14 | linxia
# Processing Record 14 of Set 14 | necochea
# Processing Record 15 of Set 14 | sompeta
# Processing Record 16 of Set 14 | xichang
# Processing Record 17 of Set 14 | leningradskiy
# Processing Record 18 of Set 14 | graham
# Processing Record 19 of Set 14 | arenys de mar
# Processing Record 20 of Set 14 | bereda
# Processing Record 21 of Set 14 | dunedin
# Processing Record 22 of Set 14 | carcassonne
# Processing Record 23 of Set 14 | nargana
# Processing Record 24 of Set 14 | omboue
# Processing Record 25 of Set 14 | aban
# Processing Record 26 of Set 14 | zomin
# Processing Record 27 of Set 14 | sabibah
# City not found. Skipping...
# Processing Record 28 of Set 14 | camacha
# Processing Record 29 of Set 14 | jerusalem
# Processing Record 30 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 14 | yacuiba
# Processing Record 32 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 14 | smoky lake
# Processing Record 34 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 14 | puqi
# Processing Record 36 of Set 14 | ulaanbaatar
# Processing Record 37 of Set 14 | dali
# Processing Record 38 of Set 14 | aljezur
# Processing Record 39 of Set 14 | gazanjyk
# Processing Record 40 of Set 14 | gornopravdinsk
# Processing Record 41 of Set 14 | kysyl-syr
# Processing Record 42 of Set 14 | lemoore
# Processing Record 43 of Set 14 | qaqortoq
# Processing Record 44 of Set 14 | velika kladusa
# Processing Record 45 of Set 14 | plettenberg bay
# Processing Record 46 of Set 14 | zitlala
# Processing Record 47 of Set 14 | dole
# Processing Record 48 of Set 14 | sechura
# Processing Record 49 of Set 14 | adrar
# Processing Record 50 of Set 14 | pokhara
# Processing Record 1 of Set 15 | bosobolo
# Processing Record 2 of Set 15 | scarborough
# Processing Record 3 of Set 15 | po
# City not found. Skipping...
# Processing Record 4 of Set 15 | mitsamiouli
# Processing Record 5 of Set 15 | rongcheng
# Processing Record 6 of Set 15 | karratha
# Processing Record 7 of Set 15 | nelson bay
# Processing Record 8 of Set 15 | kloulklubed
# Processing Record 9 of Set 15 | coihaique
# Processing Record 10 of Set 15 | ataco
# Processing Record 11 of Set 15 | vega de alatorre
# Processing Record 12 of Set 15 | raypur
# Processing Record 13 of Set 15 | marana
# Processing Record 14 of Set 15 | el cope
# Processing Record 15 of Set 15 | turukhansk
# Processing Record 16 of Set 15 | nianzishan
# Processing Record 17 of Set 15 | bitam
# Processing Record 18 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 19 of Set 15 | kralendijk
# Processing Record 20 of Set 15 | bundaberg
# Processing Record 21 of Set 15 | kropotkin
# Processing Record 22 of Set 15 | liwale
# Processing Record 23 of Set 15 | peniche
# Processing Record 24 of Set 15 | safut
# Processing Record 25 of Set 15 | kondopoga
# Processing Record 26 of Set 15 | inirida
# Processing Record 27 of Set 15 | novyy urengoy
# Processing Record 28 of Set 15 | lander
# Processing Record 29 of Set 15 | madison
# Processing Record 30 of Set 15 | ibipeba
# Processing Record 31 of Set 15 | khandagayty
# Processing Record 32 of Set 15 | hami
# Processing Record 33 of Set 15 | farafangana
# Processing Record 34 of Set 15 | pouembout
# Processing Record 35 of Set 15 | atasu
# Processing Record 36 of Set 15 | muros
# Processing Record 37 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 15 | ust-nera
# Processing Record 39 of Set 15 | atbasar
# Processing Record 40 of Set 15 | visnes
# Processing Record 41 of Set 15 | itamaraca
# Processing Record 42 of Set 15 | jumla
# Processing Record 43 of Set 15 | suntar
# Processing Record 44 of Set 15 | mackenzie
# Processing Record 45 of Set 15 | casa grande
# Processing Record 46 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 15 | palma soriano
# Processing Record 48 of Set 15 | ilinskiy
# Processing Record 49 of Set 15 | matara
# Processing Record 50 of Set 15 | dong hoi
# Processing Record 1 of Set 16 | vallenar
# Processing Record 2 of Set 16 | emba
# Processing Record 3 of Set 16 | vila
# Processing Record 4 of Set 16 | sambava
# Processing Record 5 of Set 16 | rio grande
# Processing Record 6 of Set 16 | garissa
# Processing Record 7 of Set 16 | burns lake
# Processing Record 8 of Set 16 | mahon
# Processing Record 9 of Set 16 | tongzi
# Processing Record 10 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 16 | port-gentil
# Processing Record 12 of Set 16 | mbanza-ngungu
# Processing Record 13 of Set 16 | lipin bor
# Processing Record 14 of Set 16 | ulcinj
# Processing Record 15 of Set 16 | kirakira
# Processing Record 16 of Set 16 | zhangye
# Processing Record 17 of Set 16 | morondava
# Processing Record 18 of Set 16 | chattanooga
# Processing Record 19 of Set 16 | saint-pierre
# Complete

# %%
len(city_data)
# Out:
# 700

# %%
city_data
# Out:
# [{'City': 'Raudeberg',
#   'Country': 'NO',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 45.27,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Solana Beach',
#   'Country': 'US',
#   'Lat': 32.9912,
#   'Lng': -117.2711,
#   'Max Temp': 62.67,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Current Description': 'mist'},
#  {'City': 'Hoquiam',
#   'Country': 'US',
#   'Lat': 46.9809,
#   'Lng': -123.8893,
#   'Max Temp': 52.93,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'moderate rain'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 77.4,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 52.86,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 42.91,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 41.43,
#   'Current Description': 'moderate rain'},
#  {'City': 'Westport',
#   'Country': 'US',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 58.89,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75,
#   'Humidity': 70,
#   'Cloudiness': 16,
#   'Wind Speed': 5.64,
#   'Current Description': 'few clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 25.7,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 12.51,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Current Description': 'light snow'},
#  {'City': 'Nemuro',
#   'Country': 'JP',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 45.25,
#   'Humidity': 71,
#   'Cloudiness': 52,
#   'Wind Speed': 10.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81.9,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'moderate rain'},
#  {'City': 'Oskarshamn',
#   'Country': 'SE',
#   'Lat': 57.2645,
#   'Lng': 16.4484,
#   'Max Temp': 45.81,
#   'Humidity': 57,
#   'Cloudiness': 7,
#   'Wind Speed': 8.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.46,
#   'Humidity': 81,
#   'Cloudiness': 57,
#   'Wind Speed': 20.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 17.67,
#   'Humidity': 85,
#   'Cloudiness': 68,
#   'Wind Speed': 3.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 64.89,
#   'Humidity': 58,
#   'Cloudiness': 2,
#   'Wind Speed': 26.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 30.22,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Current Description': 'light snow'},
#  {'City': 'Warmbad',
#   'Country': 'NA',
#   'Lat': -28.45,
#   'Lng': 18.7333,
#   'Max Temp': 60.82,
#   'Humidity': 51,
#   'Cloudiness': 77,
#   'Wind Speed': 9.73,
#   'Current Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 24.15,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 76.1,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 10.02,
#   'Current Description': 'few clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.9,
#   'Humidity': 66,
#   'Cloudiness': 78,
#   'Wind Speed': 13.51,
#   'Current Description': 'light rain'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.32,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 61.54,
#   'Humidity': 42,
#   'Cloudiness': 7,
#   'Wind Speed': 1.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 76.35,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 11.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Tambo',
#   'Country': 'PE',
#   'Lat': -14.8,
#   'Lng': -73.9167,
#   'Max Temp': 52.41,
#   'Humidity': 24,
#   'Cloudiness': 7,
#   'Wind Speed': 8.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 76.08,
#   'Humidity': 77,
#   'Cloudiness': 27,
#   'Wind Speed': 10.04,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Castanos',
#   'Country': 'MX',
#   'Lat': 26.7833,
#   'Lng': -101.4167,
#   'Max Temp': 74.97,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Montepuez',
#   'Country': 'MZ',
#   'Lat': -13.1256,
#   'Lng': 38.9997,
#   'Max Temp': 91.9,
#   'Humidity': 21,
#   'Cloudiness': 7,
#   'Wind Speed': 4.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 56.08,
#   'Humidity': 85,
#   'Cloudiness': 2,
#   'Wind Speed': 7.56,
#   'Current Description': 'clear sky'},
#  {'City': 'Emerald',
#   'Country': 'AU',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 77.14,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 63.36,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Niteroi',
#   'Country': 'BR',
#   'Lat': -22.8833,
#   'Lng': -43.1036,
#   'Max Temp': 83.86,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.86,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 37.04,
#   'Humidity': 75,
#   'Cloudiness': 30,
#   'Wind Speed': 6.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.26,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Current Description': 'light rain'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 77.05,
#   'Humidity': 53,
#   'Cloudiness': 53,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mezen',
#   'Country': 'RU',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 29.14,
#   'Humidity': 90,
#   'Cloudiness': 80,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.79,
#   'Humidity': 76,
#   'Cloudiness': 21,
#   'Wind Speed': 17.69,
#   'Current Description': 'few clouds'},
#  {'City': 'Embonas',
#   'Country': 'GR',
#   'Lat': 36.2269,
#   'Lng': 27.8564,
#   'Max Temp': 66.83,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 9.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Ola',
#   'Country': 'RU',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 25.21,
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 14.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 71.96,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 10.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 75.54,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 63.84,
#   'Humidity': 70,
#   'Cloudiness': 43,
#   'Wind Speed': 18.28,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lithakia',
#   'Country': 'GR',
#   'Lat': 37.7167,
#   'Lng': 20.8333,
#   'Max Temp': 72.77,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 65.73,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Current Description': 'moderate rain'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 73.22,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mannarakkat',
#   'Country': 'IN',
#   'Lat': 10.9833,
#   'Lng': 76.4667,
#   'Max Temp': 80.15,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 37.62,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 34.61,
#   'Humidity': 83,
#   'Cloudiness': 7,
#   'Wind Speed': 3.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Mokhotlong',
#   'Country': 'LS',
#   'Lat': -29.2894,
#   'Lng': 29.0675,
#   'Max Temp': 65.43,
#   'Humidity': 17,
#   'Cloudiness': 5,
#   'Wind Speed': 24.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 10.67,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 30.88,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 6.67,
#   'Current Description': 'light snow'},
#  {'City': 'Norsup',
#   'Country': 'VU',
#   'Lat': -16.0667,
#   'Lng': 167.3833,
#   'Max Temp': 78.44,
#   'Humidity': 86,
#   'Cloudiness': 77,
#   'Wind Speed': 8.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 52.66,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'light rain'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 65.26,
#   'Humidity': 63,
#   'Cloudiness': 50,
#   'Wind Speed': 32.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kalmunai',
#   'Country': 'LK',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 79.99,
#   'Humidity': 79,
#   'Cloudiness': 81,
#   'Wind Speed': 1.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.11,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 12.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Markova',
#   'Country': 'UA',
#   'Lat': 48.6758,
#   'Lng': 24.4138,
#   'Max Temp': 47.79,
#   'Humidity': 57,
#   'Cloudiness': 86,
#   'Wind Speed': 7.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namtsy',
#   'Country': 'RU',
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp': 14.11,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 1.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 50.92,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 40.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 77.49,
#   'Humidity': 84,
#   'Cloudiness': 68,
#   'Wind Speed': 11.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 69.96,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 69.1,
#   'Humidity': 48,
#   'Cloudiness': 67,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 46.54,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04,
#   'Current Description': 'light snow'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 64.81,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 95.99,
#   'Humidity': 36,
#   'Cloudiness': 84,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.42,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.55,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 71.65,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 20.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Bodden Town',
#   'Country': 'KY',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 87.01,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 68.05,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'light rain'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 53.02,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 50.83,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 67.1,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 31.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 22.46,
#   'Humidity': 93,
#   'Cloudiness': 63,
#   'Wind Speed': 19.64,
#   'Current Description': 'broken clouds'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 81.77,
#   'Humidity': 61,
#   'Cloudiness': 10,
#   'Wind Speed': 3.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 75.13,
#   'Humidity': 64,
#   'Cloudiness': 59,
#   'Wind Speed': 12.62,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 22.55,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.91,
#   'Current Description': 'light snow'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 40.41,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Matam',
#   'Country': 'SN',
#   'Lat': 15.6175,
#   'Lng': -13.3303,
#   'Max Temp': 100.31,
#   'Humidity': 13,
#   'Cloudiness': 4,
#   'Wind Speed': 7.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Oksovskiy',
#   'Country': 'RU',
#   'Lat': 62.6062,
#   'Lng': 39.8984,
#   'Max Temp': 31.44,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 7.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Comba',
#   'Country': 'ES',
#   'Lat': 43.0331,
#   'Lng': -8.8093,
#   'Max Temp': 59.68,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44,
#   'Current Description': 'light rain'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 27.54,
#   'Humidity': 94,
#   'Cloudiness': 53,
#   'Wind Speed': 2.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Waddan',
#   'Country': 'LY',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 93.58,
#   'Humidity': 13,
#   'Cloudiness': 93,
#   'Wind Speed': 14.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 55.98,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 72,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 70.32,
#   'Humidity': 77,
#   'Cloudiness': 84,
#   'Wind Speed': 1.01,
#   'Current Description': 'light rain'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 89.76,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 14.18,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 16.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aleksandrovsk-Sakhalinskiy',
#   'Country': 'RU',
#   'Lat': 50.8975,
#   'Lng': 142.1561,
#   'Max Temp': 37.6,
#   'Humidity': 88,
#   'Cloudiness': 76,
#   'Wind Speed': 7.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.19,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 4.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -1.03,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 8.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 43.2,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 15.59,
#   'Current Description': 'clear sky'},
#  {'City': 'Shenzhen',
#   'Country': 'CN',
#   'Lat': 22.5455,
#   'Lng': 114.0683,
#   'Max Temp': 70.21,
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 7.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 72.01,
#   'Humidity': 76,
#   'Cloudiness': 53,
#   'Wind Speed': 5.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 55.89,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 89.11,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Current Description': 'moderate rain'},
#  {'City': 'Perevolotskiy',
#   'Country': 'RU',
#   'Lat': 51.8763,
#   'Lng': 54.1938,
#   'Max Temp': 50.92,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 48.2,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ben Tre',
#   'Country': 'VN',
#   'Lat': 10.2333,
#   'Lng': 106.3833,
#   'Max Temp': 75.94,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 1.86,
#   'Current Description': 'light rain'},
#  {'City': 'Manadhoo',
#   'Country': 'MV',
#   'Lat': 5.7667,
#   'Lng': 73.3833,
#   'Max Temp': 81.43,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 14.23,
#   'Current Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'light rain'},
#  {'City': 'Baghdad',
#   'Country': 'IQ',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 80.51,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 47.01,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ugoofaaru',
#   'Country': 'MV',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 81.27,
#   'Humidity': 78,
#   'Cloudiness': 14,
#   'Wind Speed': 13.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Birao',
#   'Country': 'CF',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 90.09,
#   'Humidity': 46,
#   'Cloudiness': 84,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.45,
#   'Humidity': 71,
#   'Cloudiness': 74,
#   'Wind Speed': 10.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kovur',
#   'Country': 'IN',
#   'Lat': 14.4833,
#   'Lng': 79.9833,
#   'Max Temp': 82.38,
#   'Humidity': 75,
#   'Cloudiness': 93,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 28.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moundou',
#   'Country': 'TD',
#   'Lat': 8.5667,
#   'Lng': 16.0833,
#   'Max Temp': 91.63,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Baykit',
#   'Country': 'RU',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 33.46,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 10.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -8.79,
#   'Humidity': 99,
#   'Cloudiness': 89,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santo Antonio Do Ica',
#   'Country': 'BR',
#   'Lat': -3.1022,
#   'Lng': -67.9397,
#   'Max Temp': 92.14,
#   'Humidity': 49,
#   'Cloudiness': 32,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aketi',
#   'Country': 'CD',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 82.44,
#   'Humidity': 64,
#   'Cloudiness': 92,
#   'Wind Speed': 1.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khvoynaya',
#   'Country': 'RU',
#   'Lat': 58.9,
#   'Lng': 34.5333,
#   'Max Temp': 38.35,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dalianwan',
#   'Country': 'CN',
#   'Lat': 39.0286,
#   'Lng': 121.695,
#   'Max Temp': 44.64,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 61.14,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 12.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 72.81,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'moderate rain'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 51.64,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 17.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 80.55,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Camocim',
#   'Country': 'BR',
#   'Lat': -2.9022,
#   'Lng': -40.8411,
#   'Max Temp': 90.37,
#   'Humidity': 54,
#   'Cloudiness': 92,
#   'Wind Speed': 13.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 57.54,
#   'Humidity': 27,
#   'Cloudiness': 4,
#   'Wind Speed': 19.28,
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 67.14,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 26.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Severiano Melo',
#   'Country': 'BR',
#   'Lat': -5.7772,
#   'Lng': -37.9578,
#   'Max Temp': 92.95,
#   'Humidity': 39,
#   'Cloudiness': 91,
#   'Wind Speed': 5.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -4.67,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kurilsk',
#   'Country': 'RU',
#   'Lat': 45.2333,
#   'Lng': 147.8833,
#   'Max Temp': 44.92,
#   'Humidity': 64,
#   'Cloudiness': 88,
#   'Wind Speed': 12.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Fernando',
#   'Country': 'PH',
#   'Lat': 15.0286,
#   'Lng': 120.6898,
#   'Max Temp': 80.15,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 63.55,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 38.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Current Description': 'light rain'},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 53.94,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'mist'},
#  {'City': 'Clinton',
#   'Country': 'US',
#   'Lat': 42.587,
#   'Lng': -82.9199,
#   'Max Temp': 49.96,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Athabasca',
#   'Country': 'CA',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 33.04,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Current Description': 'snow'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 75.49,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 50.61,
#   'Humidity': 68,
#   'Cloudiness': 57,
#   'Wind Speed': 4.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ha Giang',
#   'Country': 'VN',
#   'Lat': 22.8333,
#   'Lng': 104.9833,
#   'Max Temp': 63.25,
#   'Humidity': 87,
#   'Cloudiness': 61,
#   'Wind Speed': 1.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 62.89,
#   'Humidity': 89,
#   'Cloudiness': 92,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Benguela',
#   'Country': 'AO',
#   'Lat': -12.5763,
#   'Lng': 13.4055,
#   'Max Temp': 79.18,
#   'Humidity': 64,
#   'Cloudiness': 62,
#   'Wind Speed': 5.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Abalak',
#   'Country': 'RU',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 46.8,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 74.84,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'light rain'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 22.98,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 11.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Termoli',
#   'Country': 'IT',
#   'Lat': 41.9888,
#   'Lng': 14.9895,
#   'Max Temp': 63.23,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 76.21,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chissamba',
#   'Country': 'AO',
#   'Lat': -12.1667,
#   'Lng': 17.3333,
#   'Max Temp': 78.73,
#   'Humidity': 52,
#   'Cloudiness': 74,
#   'Wind Speed': 4.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Killybegs',
#   'Country': 'IE',
#   'Lat': 54.6333,
#   'Lng': -8.45,
#   'Max Temp': 53.31,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 25.23,
#   'Current Description': 'light rain'},
#  {'City': 'Caracuaro',
#   'Country': 'MX',
#   'Lat': 19.0106,
#   'Lng': -101.1264,
#   'Max Temp': 74.08,
#   'Humidity': 84,
#   'Cloudiness': 74,
#   'Wind Speed': 0.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Humaita',
#   'Country': 'BR',
#   'Lat': -7.5061,
#   'Lng': -63.0208,
#   'Max Temp': 95.97,
#   'Humidity': 40,
#   'Cloudiness': 38,
#   'Wind Speed': 5.14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 78.64,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 53.15,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'mist'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 80.91,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 5.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 76.55,
#   'Humidity': 83,
#   'Cloudiness': 11,
#   'Wind Speed': 4.68,
#   'Current Description': 'few clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 67.46,
#   'Humidity': 76,
#   'Cloudiness': 81,
#   'Wind Speed': 19.26,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jagdalpur',
#   'Country': 'IN',
#   'Lat': 19.0667,
#   'Lng': 82.0333,
#   'Max Temp': 70.61,
#   'Humidity': 71,
#   'Cloudiness': 67,
#   'Wind Speed': 4.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 64.02,
#   'Humidity': 82,
#   'Cloudiness': 8,
#   'Wind Speed': 7.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 32.07,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 31.57,
#   'Humidity': 47,
#   'Cloudiness': 13,
#   'Wind Speed': 21.81,
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.76,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luwuk',
#   'Country': 'ID',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 78.12,
#   'Humidity': 74,
#   'Cloudiness': 95,
#   'Wind Speed': 3.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 74.97,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 48.2,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 87.15,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 7.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 55.78,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cedartown',
#   'Country': 'US',
#   'Lat': 34.0537,
#   'Lng': -85.255,
#   'Max Temp': 63.81,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 6.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 82.65,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Honningsvag',
#   'Country': 'NO',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 35.2,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 13.67,
#   'Current Description': 'light rain'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 83.93,
#   'Humidity': 73,
#   'Cloudiness': 78,
#   'Wind Speed': 9.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mawlaik',
#   'Country': 'MM',
#   'Lat': 23.6333,
#   'Lng': 94.4167,
#   'Max Temp': 73.26,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 1.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 45.21,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hakkari',
#   'Country': 'TR',
#   'Lat': 37.5833,
#   'Lng': 44.1667,
#   'Max Temp': 44.38,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Smidovich',
#   'Country': 'RU',
#   'Lat': 48.6,
#   'Lng': 133.8167,
#   'Max Temp': 41,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 9.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Obihiro',
#   'Country': 'JP',
#   'Lat': 42.9172,
#   'Lng': 143.2044,
#   'Max Temp': 36.32,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 3.96,
#   'Current Description': 'clear sky'},
#  {'City': 'George Town',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81.9,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 55.69,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 15.88,
#   'Current Description': 'light rain'},
#  {'City': 'Mango',
#   'Country': 'US',
#   'Lat': 27.9797,
#   'Lng': -82.3065,
#   'Max Temp': 84.27,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Naryan-Mar',
#   'Country': 'RU',
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 27.52,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 12.73,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mecca',
#   'Country': 'SA',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 88.57,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 10.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 55.96,
#   'Humidity': 48,
#   'Cloudiness': 3,
#   'Wind Speed': 5.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Louis',
#   'Country': 'SN',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 99.68,
#   'Humidity': 11,
#   'Cloudiness': 3,
#   'Wind Speed': 6.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Rudnogorsk',
#   'Country': 'RU',
#   'Lat': 57.2639,
#   'Lng': 103.7519,
#   'Max Temp': 30.29,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 6.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lazaro Cardenas',
#   'Country': 'MX',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 79.7,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 3.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 58.32,
#   'Humidity': 82,
#   'Cloudiness': 84,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 44.11,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'light rain'},
#  {'City': 'Celestun',
#   'Country': 'MX',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 77.34,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Prilep',
#   'Country': 'MK',
#   'Lat': 41.3464,
#   'Lng': 21.5544,
#   'Max Temp': 57.72,
#   'Humidity': 59,
#   'Cloudiness': 59,
#   'Wind Speed': 2.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 76.87,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tabou',
#   'Country': 'CI',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 80.29,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 8.21,
#   'Current Description': 'light rain'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.94,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 86.83,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 62.38,
#   'Humidity': 83,
#   'Cloudiness': 45,
#   'Wind Speed': 10.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 66.69,
#   'Humidity': 76,
#   'Cloudiness': 5,
#   'Wind Speed': 14.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 79.56,
#   'Humidity': 76,
#   'Cloudiness': 22,
#   'Wind Speed': 6.98,
#   'Current Description': 'few clouds'},
#  {'City': 'Paso De Los Toros',
#   'Country': 'UY',
#   'Lat': -32.8167,
#   'Lng': -56.5167,
#   'Max Temp': 61.36,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Iranshahr',
#   'Country': 'IR',
#   'Lat': 27.2025,
#   'Lng': 60.6848,
#   'Max Temp': 79.14,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 80.28,
#   'Humidity': 67,
#   'Cloudiness': 76,
#   'Wind Speed': 9.1,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cheremukhovo',
#   'Country': 'RU',
#   'Lat': 60.3484,
#   'Lng': 59.9851,
#   'Max Temp': 39.6,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 10.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 5.43,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -7.89,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 70.92,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fereydun Kenar',
#   'Country': 'IR',
#   'Lat': 36.6864,
#   'Lng': 52.5225,
#   'Max Temp': 61.11,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 2.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 25.56,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 19.42,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 25.32,
#   'Current Description': 'shower snow'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 75.65,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 49.41,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 28.58,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -1.77,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 3.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 9.03,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chingola',
#   'Country': 'ZM',
#   'Lat': -12.529,
#   'Lng': 27.8838,
#   'Max Temp': 86.94,
#   'Humidity': 25,
#   'Cloudiness': 91,
#   'Wind Speed': 2.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Solnechnyy',
#   'Country': 'RU',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 33.53,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 3.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 89.96,
#   'Humidity': 51,
#   'Cloudiness': 82,
#   'Wind Speed': 15.23,
#   'Current Description': 'broken clouds'},
#  {'City': 'Murgab',
#   'Country': 'TM',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 57.07,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 58.37,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'mist'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 56.68,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Monte Carmelo',
#   'Country': 'BR',
#   'Lat': -18.7247,
#   'Lng': -47.4986,
#   'Max Temp': 88.23,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Edd',
#   'Country': 'ER',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 89.69,
#   'Humidity': 55,
#   'Cloudiness': 35,
#   'Wind Speed': 14.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 84,
#   'Humidity': 71,
#   'Cloudiness': 53,
#   'Wind Speed': 9.6,
#   'Current Description': 'light rain'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 74.97,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'light rain'},
#  {'City': 'Ulety',
#   'Country': 'RU',
#   'Lat': 51.3572,
#   'Lng': 112.4849,
#   'Max Temp': 34.09,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 58.73,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 66.96,
#   'Humidity': 75,
#   'Cloudiness': 9,
#   'Wind Speed': 13.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Fethiye',
#   'Country': 'TR',
#   'Lat': 36.6217,
#   'Lng': 29.1164,
#   'Max Temp': 73.27,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 37.31,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 84.34,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 13.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 81.16,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inzhavino',
#   'Country': 'RU',
#   'Lat': 52.3185,
#   'Lng': 42.4937,
#   'Max Temp': 49.73,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 6.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 43.25,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Budelsdorf',
#   'Country': 'DE',
#   'Lat': 54.3167,
#   'Lng': 9.6833,
#   'Max Temp': 53.42,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kingston',
#   'Country': 'JM',
#   'Lat': 17.997,
#   'Lng': -76.7936,
#   'Max Temp': 87.21,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 76.96,
#   'Humidity': 74,
#   'Cloudiness': 80,
#   'Wind Speed': 1.81,
#   'Current Description': 'light rain'},
#  {'City': 'Yola',
#   'Country': 'NG',
#   'Lat': 9.2,
#   'Lng': 12.4833,
#   'Max Temp': 91.81,
#   'Humidity': 45,
#   'Cloudiness': 34,
#   'Wind Speed': 4.63,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rucphen',
#   'Country': 'NL',
#   'Lat': 51.5317,
#   'Lng': 4.5583,
#   'Max Temp': 58.93,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 97.66,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 11.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Yichang',
#   'Country': 'CN',
#   'Lat': 30.7144,
#   'Lng': 111.2847,
#   'Max Temp': 55.62,
#   'Humidity': 57,
#   'Cloudiness': 6,
#   'Wind Speed': 2.68,
#   'Current Description': 'light rain'},
#  {'City': 'Kulai',
#   'Country': 'MY',
#   'Lat': 1.6561,
#   'Lng': 103.6032,
#   'Max Temp': 80.42,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 3.2,
#   'Current Description': 'few clouds'},
#  {'City': 'Black River',
#   'Country': 'JM',
#   'Lat': 18.0264,
#   'Lng': -77.8487,
#   'Max Temp': 88.99,
#   'Humidity': 61,
#   'Cloudiness': 41,
#   'Wind Speed': 9.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 32.16,
#   'Humidity': 85,
#   'Cloudiness': 17,
#   'Wind Speed': 2.19,
#   'Current Description': 'few clouds'},
#  {'City': 'Sembakung',
#   'Country': 'ID',
#   'Lat': 3.8167,
#   'Lng': 117.25,
#   'Max Temp': 73.15,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Current Description': 'moderate rain'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 79.36,
#   'Humidity': 80,
#   'Cloudiness': 50,
#   'Wind Speed': 7.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 90.46,
#   'Humidity': 33,
#   'Cloudiness': 79,
#   'Wind Speed': 3.18,
# ...
#   'Country': 'CN',
#   'Lat': 29.7167,
#   'Lng': 113.8833,
#   'Max Temp': 55.94,
#   'Humidity': 71,
#   'Cloudiness': 46,
#   'Wind Speed': 3.47,
#   'Current Description': 'light rain'},
#  {'City': 'Ulaanbaatar',
#   'Country': 'MN',
#   'Lat': 47.9077,
#   'Lng': 106.8832,
#   'Max Temp': 23.13,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Dali',
#   'Country': 'CN',
#   'Lat': 25.7,
#   'Lng': 100.1833,
#   'Max Temp': 54.97,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Aljezur',
#   'Country': 'PT',
#   'Lat': 37.3191,
#   'Lng': -8.8033,
#   'Max Temp': 71.29,
#   'Humidity': 43,
#   'Cloudiness': 15,
#   'Wind Speed': 6.53,
#   'Current Description': 'few clouds'},
#  {'City': 'Gazanjyk',
#   'Country': 'TM',
#   'Lat': 39.2446,
#   'Lng': 55.5154,
#   'Max Temp': 61.5,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Gornopravdinsk',
#   'Country': 'RU',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 45.5,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 15.66,
#   'Current Description': 'light rain'},
#  {'City': 'Kysyl-Syr',
#   'Country': 'RU',
#   'Lat': 63.8986,
#   'Lng': 122.7617,
#   'Max Temp': 30.51,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'light snow'},
#  {'City': 'Lemoore',
#   'Country': 'US',
#   'Lat': 36.3008,
#   'Lng': -119.7829,
#   'Max Temp': 57.54,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 37.9,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 7.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Velika Kladusa',
#   'Country': 'BA',
#   'Lat': 45.1894,
#   'Lng': 15.8117,
#   'Max Temp': 53.2,
#   'Humidity': 64,
#   'Cloudiness': 45,
#   'Wind Speed': 5.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Plettenberg Bay',
#   'Country': 'ZA',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 59.95,
#   'Humidity': 74,
#   'Cloudiness': 31,
#   'Wind Speed': 18.28,
#   'Current Description': 'light rain'},
#  {'City': 'Zitlala',
#   'Country': 'MX',
#   'Lat': 17.6333,
#   'Lng': -99.0833,
#   'Max Temp': 60.13,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dole',
#   'Country': 'FR',
#   'Lat': 47.0833,
#   'Lng': 5.5,
#   'Max Temp': 56.82,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 70.16,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 90.05,
#   'Humidity': 13,
#   'Cloudiness': 34,
#   'Wind Speed': 1.88,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pokhara',
#   'Country': 'NP',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 64.56,
#   'Humidity': 90,
#   'Cloudiness': 68,
#   'Wind Speed': 2.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bosobolo',
#   'Country': 'CD',
#   'Lat': 4.1833,
#   'Lng': 19.9,
#   'Max Temp': 86.94,
#   'Humidity': 62,
#   'Cloudiness': 15,
#   'Wind Speed': 2.08,
#   'Current Description': 'few clouds'},
#  {'City': 'Scarborough',
#   'Country': 'GB',
#   'Lat': 54.2797,
#   'Lng': -0.4044,
#   'Max Temp': 55.22,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 79.7,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Rongcheng',
#   'Country': 'CN',
#   'Lat': 30.634,
#   'Lng': 117.8517,
#   'Max Temp': 56.89,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Current Description': 'light rain'},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 81.36,
#   'Humidity': 49,
#   'Cloudiness': 76,
#   'Wind Speed': 8.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nelson Bay',
#   'Country': 'AU',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 68,
#   'Humidity': 96,
#   'Cloudiness': 62,
#   'Wind Speed': 4.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 50.61,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Ataco',
#   'Country': 'CO',
#   'Lat': 3.5915,
#   'Lng': -75.3818,
#   'Max Temp': 79.86,
#   'Humidity': 73,
#   'Cloudiness': 98,
#   'Wind Speed': 1.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vega De Alatorre',
#   'Country': 'MX',
#   'Lat': 20.0333,
#   'Lng': -96.6333,
#   'Max Temp': 79.68,
#   'Humidity': 72,
#   'Cloudiness': 35,
#   'Wind Speed': 7.34,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Raypur',
#   'Country': 'IN',
#   'Lat': 22.4108,
#   'Lng': 88.5094,
#   'Max Temp': 82.36,
#   'Humidity': 72,
#   'Cloudiness': 44,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marana',
#   'Country': 'US',
#   'Lat': 32.4367,
#   'Lng': -111.2254,
#   'Max Temp': 72.34,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'El Cope',
#   'Country': 'PA',
#   'Lat': 8.6167,
#   'Lng': -80.6,
#   'Max Temp': 76.46,
#   'Humidity': 76,
#   'Cloudiness': 52,
#   'Wind Speed': 0.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 32.14,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.38,
#   'Current Description': 'light snow'},
#  {'City': 'Nianzishan',
#   'Country': 'CN',
#   'Lat': 47.5167,
#   'Lng': 122.8833,
#   'Max Temp': 43.21,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Bitam',
#   'Country': 'GA',
#   'Lat': 2.076,
#   'Lng': 11.5007,
#   'Max Temp': 79.38,
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 4.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kralendijk',
#   'Country': 'BQ',
#   'Lat': 12.15,
#   'Lng': -68.2667,
#   'Max Temp': 87.78,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bundaberg',
#   'Country': 'AU',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 77.22,
#   'Humidity': 86,
#   'Cloudiness': 48,
#   'Wind Speed': 5.99,
#   'Current Description': 'light rain'},
#  {'City': 'Kropotkin',
#   'Country': 'RU',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 61.18,
#   'Humidity': 52,
#   'Cloudiness': 97,
#   'Wind Speed': 7.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Liwale',
#   'Country': 'TZ',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp': 89.83,
#   'Humidity': 27,
#   'Cloudiness': 44,
#   'Wind Speed': 7.63,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Peniche',
#   'Country': 'PT',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 77.61,
#   'Humidity': 58,
#   'Cloudiness': 94,
#   'Wind Speed': 10.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Safut',
#   'Country': 'JO',
#   'Lat': 32.0336,
#   'Lng': 35.8332,
#   'Max Temp': 67.78,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Kondopoga',
#   'Country': 'RU',
#   'Lat': 62.2057,
#   'Lng': 34.2614,
#   'Max Temp': 35.28,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inirida',
#   'Country': 'CO',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 88.59,
#   'Humidity': 62,
#   'Cloudiness': 57,
#   'Wind Speed': 2.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'Novyy Urengoy',
#   'Country': 'RU',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': 31.5,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Current Description': 'light snow'},
#  {'City': 'Lander',
#   'Country': 'US',
#   'Lat': 42.833,
#   'Lng': -108.7307,
#   'Max Temp': 45.99,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Madison',
#   'Country': 'US',
#   'Lat': 34.7334,
#   'Lng': -86.5667,
#   'Max Temp': 64.45,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Ibipeba',
#   'Country': 'BR',
#   'Lat': -11.6408,
#   'Lng': -42.0111,
#   'Max Temp': 83.68,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khandagayty',
#   'Country': 'RU',
#   'Lat': 50.7333,
#   'Lng': 92.05,
#   'Max Temp': 32.59,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 52.27,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Farafangana',
#   'Country': 'MG',
#   'Lat': -22.8167,
#   'Lng': 47.8333,
#   'Max Temp': 74.62,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 8.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Pouembout',
#   'Country': 'NC',
#   'Lat': -21.1333,
#   'Lng': 164.9,
#   'Max Temp': 69.04,
#   'Humidity': 93,
#   'Cloudiness': 13,
#   'Wind Speed': 5.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Atasu',
#   'Country': 'KZ',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 44.55,
#   'Humidity': 47,
#   'Cloudiness': 6,
#   'Wind Speed': 15.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 63.99,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Nera',
#   'Country': 'RU',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -0.18,
#   'Humidity': 99,
#   'Cloudiness': 91,
#   'Wind Speed': 1.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atbasar',
#   'Country': 'KZ',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 51.28,
#   'Humidity': 60,
#   'Cloudiness': 31,
#   'Wind Speed': 18.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Visnes',
#   'Country': 'NO',
#   'Lat': 59.3556,
#   'Lng': 5.2242,
#   'Max Temp': 49.57,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Itamaraca',
#   'Country': 'BR',
#   'Lat': -7.7478,
#   'Lng': -34.8256,
#   'Max Temp': 86.68,
#   'Humidity': 66,
#   'Cloudiness': 43,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 49.51,
#   'Humidity': 91,
#   'Cloudiness': 7,
#   'Wind Speed': 4.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Suntar',
#   'Country': 'RU',
#   'Lat': 62.1444,
#   'Lng': 117.6319,
#   'Max Temp': 39.96,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mackenzie',
#   'Country': 'CA',
#   'Lat': 55.2999,
#   'Lng': -123.1698,
#   'Max Temp': 28.62,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Casa Grande',
#   'Country': 'US',
#   'Lat': 32.8795,
#   'Lng': -111.7573,
#   'Max Temp': 72.81,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Palma Soriano',
#   'Country': 'CU',
#   'Lat': 20.2172,
#   'Lng': -75.9989,
#   'Max Temp': 83.26,
#   'Humidity': 61,
#   'Cloudiness': 61,
#   'Wind Speed': 7.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ilinskiy',
#   'Country': 'RU',
#   'Lat': 55.619,
#   'Lng': 38.1182,
#   'Max Temp': 45.52,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 78.89,
#   'Humidity': 79,
#   'Cloudiness': 9,
#   'Wind Speed': 7.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Dong Hoi',
#   'Country': 'VN',
#   'Lat': 17.4833,
#   'Lng': 106.6,
#   'Max Temp': 69.73,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vallenar',
#   'Country': 'CL',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 68.49,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Emba',
#   'Country': 'KZ',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 51.42,
#   'Humidity': 66,
#   'Cloudiness': 4,
#   'Wind Speed': 9.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 60.33,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 77.14,
#   'Humidity': 88,
#   'Cloudiness': 31,
#   'Wind Speed': 4.03,
#   'Current Description': 'light rain'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 69.91,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Garissa',
#   'Country': 'KE',
#   'Lat': -0.4536,
#   'Lng': 39.6401,
#   'Max Temp': 93.7,
#   'Humidity': 31,
#   'Cloudiness': 41,
#   'Wind Speed': 7.56,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Burns Lake',
#   'Country': 'CA',
#   'Lat': 54.2331,
#   'Lng': -125.7533,
#   'Max Temp': 33.22,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahon',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 64.96,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Current Description': 'few clouds'},
#  {'City': 'Tongzi',
#   'Country': 'CN',
#   'Lat': 28.7829,
#   'Lng': 105.0877,
#   'Max Temp': 58.93,
#   'Humidity': 74,
#   'Cloudiness': 47,
#   'Wind Speed': 1.19,
#   'Current Description': 'light rain'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 78.21,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mbanza-Ngungu',
#   'Country': 'CD',
#   'Lat': -5.25,
#   'Lng': 14.8667,
#   'Max Temp': 77.63,
#   'Humidity': 74,
#   'Cloudiness': 96,
#   'Wind Speed': 2.46,
#   'Current Description': 'moderate rain'},
#  {'City': 'Lipin Bor',
#   'Country': 'RU',
#   'Lat': 60.2622,
#   'Lng': 37.9763,
#   'Max Temp': 38.03,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.53,
#   'Current Description': 'light rain'},
#  {'City': 'Ulcinj',
#   'Country': 'ME',
#   'Lat': 41.9294,
#   'Lng': 19.2244,
#   'Max Temp': 64.62,
#   'Humidity': 80,
#   'Cloudiness': 21,
#   'Wind Speed': 1.92,
#   'Current Description': 'few clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 78.64,
#   'Humidity': 86,
#   'Cloudiness': 24,
#   'Wind Speed': 6.78,
#   'Current Description': 'few clouds'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 47.84,
#   'Humidity': 45,
#   'Cloudiness': 7,
#   'Wind Speed': 3.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 76.28,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Chattanooga',
#   'Country': 'US',
#   'Lat': 35.0456,
#   'Lng': -85.3097,
#   'Max Temp': 63.36,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 77.58,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'light rain'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Raudeberg      NO  61.9875    5.1352     45.27        72         100
# 1  Solana Beach      US  32.9912 -117.2711     62.67        91          90
# 2       Hoquiam      US  46.9809 -123.8893     52.93        65          90
# 3          Biak      ID  -0.9131  122.8766     77.40        76          98
# 4         Bluff      NZ -46.6000  168.3333     52.86        85         100
# 5  Punta Arenas      CL -53.1500  -70.9167     42.91        65          40
# 6      Westport      US  41.1415  -73.3579     58.89        58          90
# 7  Ponta Do Sol      PT  32.6667  -17.1000     75.00        70          16
# 8       Iqaluit      CA  63.7506  -68.5145     25.70        86          91
# 9         Pevek      RU  69.7008  170.3133     12.51        94         100
#
#    Wind Speed Current Description
# 0        5.01     overcast clouds
# 1        1.99                mist
# 2        9.22       moderate rain
# 3        2.24     overcast clouds
# 4        5.21     overcast clouds
# 5       41.43       moderate rain
# 6       11.50     overcast clouds
# 7        5.64          few clouds
# 8        1.99     overcast clouds
# 9        5.97          light snow

# %%
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv")
